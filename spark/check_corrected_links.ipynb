# %%
import pandas as pd
import time

# %%
# Load the data
start_t = time.time()
corrected_pagelinks_df = pd.read_pickle('/home/benjamin/wikipedia/Wikipedia/pagelinks_corrected0.npz')
print('pagelinks loaded')
print('Load Time:', time.time() - start_t)
# Out:
# pagelinks loaded
# Load Time: 6.597285032272339

# %%
corrected_pagelinks_df
# Out:
#                                                      source  \
# 0                                                    EBCDIC
# 1                                                    EBCDIC
# 2                                                    EBCDIC
# 3                                                    EBCDIC
# 4                                                    EBCDIC
# 5                                                    EBCDIC
# 6                                                    EBCDIC
# 7                                                    EBCDIC
# 8                                                  IBM_3270
# 9                                                  IBM_3270
# 10                                                 IBM_3270
# 11                                                 IBM_3270
# 12                                                 IBM_3270
# 13                                                 IBM_3270
# 14                                                 IBM_3270
# ...
