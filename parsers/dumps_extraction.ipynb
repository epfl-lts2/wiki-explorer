# %%
import gzip
import os

# %%
pagelinks_file = '/home/benjamin/wikipedia/Wikipedia/enwiki-20180801-pagelinks.sql.gz'
folder,filename = os.path.split(pagelinks_file)

# %%
data = gzip.open(pagelinks_file)

# %%
date = filename[7:15]
print(date)
# Out:
# 20180801

# %%
data.peek(5)
# Out:
# b"-- MySQL dump 10.16  Distrib 10.1.26-MariaDB, for debian-linux-gnu (x86_64)\n--\n-- Host: 10.64.48.13    Database: enwiki\n-- ------------------------------------------------------\n-- Server version\t10.1.33-MariaDB\n\n/*!40101 SET @OLD_CHARACTER_SET_CLIENT=@@CHARACTER_SET_CLIENT */;\n/*!40101 SET @OLD_CHARACTER_SET_RESULTS=@@CHARACTER_SET_RESULTS */;\n/*!40101 SET @OLD_COLLATION_CONNECTION=@@COLLATION_CONNECTION */;\n/*!40101 SET NAMES utf8mb4 */;\n/*!40103 SET @OLD_TIME_ZONE=@@TIME_ZONE */;\n/*!40103 SET TIME_ZONE='+00:00' */;\n/*!40014 SET @OLD_UNIQUE_CHECKS=@@UNIQUE_CHECKS, UNIQUE_CHECKS=0 */;\n/*!40014 SET @OLD_FOREIGN_KEY_CHECKS=@@FOREIGN_KEY_CHECKS, FOREIGN_KEY_CHECKS=0 */;\n/*!40101 SET @OLD_SQL_MODE=@@SQL_MODE, SQL_MODE='NO_AUTO_VALUE_ON_ZERO' */;\n/*!40111 SET @OLD_SQL_NOTES=@@SQL_NOTES, SQL_NOTES=0 */;\n\n--\n-- Table structure for table `pagelinks`\n--\n\nDROP TABLE IF EXISTS `pagelinks`;\n/*!40101 SET @saved_cs_client     = @@character_set_client */;\n/*!40101 SET cha
# ...

# %%
import pandas
import codecs
import time

# %%
import re
pagelinksR = re.compile("\((\d+),"      # pl_from             (source page id)
                         + "(\d+),"        # page_namespace      (namespace number)
                         + "'(.*?)',"      # page_title          (page title w/o namespace)
                         + "(\d+)\)"       # pl_from_ns          (source page namespace)
)

# %% [markdown]
# We process each line in the file. Each line is an `INSERT` sql command with a list of data tuples to insert.
#
# To count the number of lines in a gz file, we can use the command:
# `zcat file.gz | wc -l`
#
# This is 42730 for pagelinks of the english wikipedia

# %%
start = time.time()
wrapper = codecs.getreader('utf-8')
with gzip.open(file, 'rb') as f:
    wf = wrapper(f,errors='replace')
    #wf = f
    count = 0
    page_list = []
    for line in wf:
        count += 1
        info_list = linefilter.findall(line)
        #print('Length',len(info_list))
        valid_pages = [(info[0],info[2]) for info in info_list if (info[1] == '0' and info[3] == '0')]
        if valid_pages:
            page_list += valid_pages
        if (count % 100) == 0:
            print(count)
print('time:', time.time() - start)
print('Iterations', count)
# Out:
# 100
# 200
# 300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-37f83971bdbc> in <module>()
#       6     count = 0
#       7     page_list = []
# ----> 8     for line in wf:
#       9         count += 1
#      10         info_list = linefilter.findall(line)
#
# /usr/lib/python3.6/codecs.py in __next__(self)
#     642
#     643         """ Return the next decoded line from the input stream."""
# --> 644         line = self.readline()
#     645         if line:
#     646             return line
#
# /usr/lib/python3.6/codecs.py in readline(self, size, keepends)
#     584                     break
#     585                 line0withend = lines[0]
# --> 586                 line0withoutend = lines[0].splitlines(keepends=False)[0]
#     587                 if line0withend != line0withoutend: # We really have a line end
# ...

# %%
# To find the number of lines in a gz  file
def count_lines(file):
    with gzip.open(file, 'rb') as f:
        #wf = wrapper(f,errors='replace')
        #wf = f
        count = 0
        for line in f:
            count += 1
            #if (count % 1000) == 0:
            #    print(count)
    print('Nb of lines:' , count)
    return count

# %%
2757/60
# Out:
# 45.95

# %%
count
# Out:
# 348

# %%
info_list
# Out:
# [('51804818', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('51804826', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('51805735', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('51808946', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('53038056', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('53040004', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('53040123', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('53041643', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('53041772', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('53041893', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('53044607', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('53108390', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('53108779', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('53109217', '0', '1932_Pacific_Tigers_football_team', '0'),
#  ('53116198', '0', '1932_Pacific_Tigers_football_team', '0'),
# ...

# %%
valid_pages
# Out:
# [('51804818', '1932_Pacific_Tigers_football_team'),
#  ('51804826', '1932_Pacific_Tigers_football_team'),
#  ('51805735', '1932_Pacific_Tigers_football_team'),
#  ('51808946', '1932_Pacific_Tigers_football_team'),
#  ('53038056', '1932_Pacific_Tigers_football_team'),
#  ('53040004', '1932_Pacific_Tigers_football_team'),
#  ('53040123', '1932_Pacific_Tigers_football_team'),
#  ('53041643', '1932_Pacific_Tigers_football_team'),
#  ('53041772', '1932_Pacific_Tigers_football_team'),
#  ('53041893', '1932_Pacific_Tigers_football_team'),
#  ('53044607', '1932_Pacific_Tigers_football_team'),
#  ('53108390', '1932_Pacific_Tigers_football_team'),
#  ('53108779', '1932_Pacific_Tigers_football_team'),
#  ('53109217', '1932_Pacific_Tigers_football_team'),
#  ('53116198', '1932_Pacific_Tigers_football_team'),
#  ('53118165', '1932_Pacific_Tigers_football_team'),
#  ('53118675', '1932_Pacific_Tigers_football_team'),
#  ('53174583', '1932_Pacific_Tigers_football_team'),
# ...

# %%
len(page_list)
# Out:
# 7776493

# %%
# Random sample in the list
s = 1400000
page_list[s:s+100]
# Out:
# [('38395486', '1379_in_Ireland'),
#  ('38443948', '1379_in_Ireland'),
#  ('38451538', '1379_in_Ireland'),
#  ('38487813', '1379_in_Ireland'),
#  ('38496592', '1379_in_Ireland'),
#  ('38506095', '1379_in_Ireland'),
#  ('38532382', '1379_in_Ireland'),
#  ('38594531', '1379_in_Ireland'),
#  ('38751548', '1379_in_Ireland'),
#  ('38751726', '1379_in_Ireland'),
#  ('38847838', '1379_in_Ireland'),
#  ('39664006', '1379_in_Ireland'),
#  ('39943767', '1379_in_Ireland'),
#  ('40392408', '1379_in_Ireland'),
#  ('42342551', '1379_in_Ireland'),
#  ('42342570', '1379_in_Ireland'),
#  ('42342657', '1379_in_Ireland'),
#  ('42342722', '1379_in_Ireland'),
#  ('42342771', '1379_in_Ireland'),
#  ('42610920', '1379_in_Ireland'),
#  ('42610957', '1379_in_Ireland'),
#  ('42619583', '1379_in_Ireland'),
#  ('42619641', '1379_in_Ireland'),
#  ('42619689', '1379_in_Ireland'),
#  ('42619746', '1379_in_Ireland'),
#  ('42619928', '1379_in_Ireland'),
#  ('42631809', '1379_in_Ireland'),
# ...

# %% [markdown]
# ### Redirects

# %%
redirect_file = '/home/benjamin/wikipedia/Wikipedia/enwiki-20180801-redirect.sql.gz'

# %%
data = gzip.open(redirect_file)
#print(codecs.getreader('utf-8').decode(data.peek(100)))
print(data.peek(100))
# Out:
# b"-- MySQL dump 10.16  Distrib 10.1.26-MariaDB, for debian-linux-gnu (x86_64)\n--\n-- Host: 10.64.48.13    Database: enwiki\n-- ------------------------------------------------------\n-- Server version\t10.1.33-MariaDB\n\n/*!40101 SET @OLD_CHARACTER_SET_CLIENT=@@CHARACTER_SET_CLIENT */;\n/*!40101 SET @OLD_CHARACTER_SET_RESULTS=@@CHARACTER_SET_RESULTS */;\n/*!40101 SET @OLD_COLLATION_CONNECTION=@@COLLATION_CONNECTION */;\n/*!40101 SET NAMES utf8mb4 */;\n/*!40103 SET @OLD_TIME_ZONE=@@TIME_ZONE */;\n/*!40103 SET TIME_ZONE='+00:00' */;\n/*!40014 SET @OLD_UNIQUE_CHECKS=@@UNIQUE_CHECKS, UNIQUE_CHECKS=0 */;\n/*!40014 SET @OLD_FOREIGN_KEY_CHECKS=@@FOREIGN_KEY_CHECKS, FOREIGN_KEY_CHECKS=0 */;\n/*!40101 SET @OLD_SQL_MODE=@@SQL_MODE, SQL_MODE='NO_AUTO_VALUE_ON_ZERO' */;\n/*!40111 SET @OLD_SQL_NOTES=@@SQL_NOTES, SQL_NOTES=0 */;\n\n--\n-- Table structure for table `redirect`\n--\n\nDROP TABLE IF EXISTS `redirect`;\n/*!40101 SET @saved_cs_client     = @@character_set_client */;\n/*!40101 SET chara
# ...

# %%
redirectR = re.compile("\((\d+),"      # rd_from (page ID number)
                         + "(\d+),"        # rd_namespace
                         + "'(.*?)',"      # rd_title
                         + "(.*?),"        # rd_interwiki
                         + "(.*?)\)"       # rd_fragment
        )

# %%
count_lines(redirect_file)
# Out:
# Nb of lines: 498
# 498

# %%
start = time.time()
wrapper = codecs.getreader('utf-8')
with gzip.open(redirect_file, 'rb') as f:
    wf = wrapper(f,errors='replace')
    #wf = f
    count = 0
    redirect_list = []
    for line in wf:
        count += 1
        info_list = redirectR.findall(line)
        #print('Length',len(info_list))
        valid_pages = [(info[0],info[2]) for info in info_list if (info[1] == '0')]
        if valid_pages:
            redirect_list += valid_pages
        if (count % 100) == 0:
            print(count)
print('time:', time.time() - start)
print('Iterations', count)
# Out:
# 100
# 200
# 300
# 400
# time: 52.179298400878906
# Iterations 498

# %%
len(page_list)
# Out:
# 8500104

# %% [markdown]
# ## Pages

# %%
pageid_file = '/home/benjamin/wikipedia/Wikipedia/enwiki-20180801-page.sql.gz'

# %%
data = gzip.open(pageid_file)
#print(codecs.getreader('utf-8').decode(data.peek(100)))
print(data.peek(100))
# Out:
# b"-- MySQL dump 10.16  Distrib 10.1.26-MariaDB, for debian-linux-gnu (x86_64)\n--\n-- Host: 10.64.48.13    Database: enwiki\n-- ------------------------------------------------------\n-- Server version\t10.1.33-MariaDB\n\n/*!40101 SET @OLD_CHARACTER_SET_CLIENT=@@CHARACTER_SET_CLIENT */;\n/*!40101 SET @OLD_CHARACTER_SET_RESULTS=@@CHARACTER_SET_RESULTS */;\n/*!40101 SET @OLD_COLLATION_CONNECTION=@@COLLATION_CONNECTION */;\n/*!40101 SET NAMES utf8mb4 */;\n/*!40103 SET @OLD_TIME_ZONE=@@TIME_ZONE */;\n/*!40103 SET TIME_ZONE='+00:00' */;\n/*!40014 SET @OLD_UNIQUE_CHECKS=@@UNIQUE_CHECKS, UNIQUE_CHECKS=0 */;\n/*!40014 SET @OLD_FOREIGN_KEY_CHECKS=@@FOREIGN_KEY_CHECKS, FOREIGN_KEY_CHECKS=0 */;\n/*!40101 SET @OLD_SQL_MODE=@@SQL_MODE, SQL_MODE='NO_AUTO_VALUE_ON_ZERO' */;\n/*!40111 SET @OLD_SQL_NOTES=@@SQL_NOTES, SQL_NOTES=0 */;\n\n--\n-- Table structure for table `page`\n--\n\nDROP TABLE IF EXISTS `page`;\n/*!40101 SET @saved_cs_client     = @@character_set_client */;\n/*!40101 SET character_set
# ...

# %%
pageidR = re.compile("\((\d+),"      # page_id             (page ID number)
                         + "(\d+),"        # page_namespace      (namespace number)
                         + "'(.*?)',"      # page_title          (page title w/o namespace)
                         + "'(.*?)',"      # page_restrictions   (protected pages have 'sysop' here)
                         + "(\d+),"        # page_counter        (view counter, disabled on WP)
                         + "([01]),"       # page_is_redirect
                         + "([01]),"       # page_is_new
                         + "([\d\.]+?),"   # page_random         (for random page function)
                         + "'(\d{14})',"   # page_touched        (cache update timestamp)
                         + "(.*?),"        # page_links updated (timestamp or null)
                         + "(\d+),"        # page_latest      (namespace number)
                         + "(\d+),"        # page_len      (namespace number)
                         + "(.*?)\)"       # page_content_model          (page content model)
        )

# %%
count_lines(pageid_file)
# Out:
# Nb of lines: 5362
# 5362

# %%
start = time.time()
wrapper = codecs.getreader('utf-8')
with gzip.open(pageid_file, 'rb') as f:
    wf = wrapper(f,errors='replace')
    #wf = f
    count = 0
    pageid_list = []
    for line in wf:
        count += 1
        info_list = pageidR.findall(line)
        #print('Length',len(info_list))
        valid_pages = [(info[0],info[2]) for info in info_list if (info[1] == '0')]
        if valid_pages:
            pageid_list += valid_pages
        if (count % 100) == 0:
            print(count)
print('time:', time.time() - start)
print('Iterations', count)

# %%
def reduce2ns_pagelinks(data_list,namespace):
    namespace = str(namespace)
    return [(info[0],info[2]) for info in data_list if (info[1] == namespace and info[3] == namespace)]
def reduce2ns_redirect(data_list,namespace):
    namespace = str(namespace)
    return [(info[0],info[2]) for info in data_list if (info[1] == namespace)]
def reduce2ns_page(data_list,namespace):
    namespace = str(namespace)
    return [(info[0],info[2]) for info in data_list if (info[1] == namespace)]

# %%
def file2df(file,regexparser,reduce2ns,ns):
    with gzip.open(file, 'rb') as f:
        wf = wrapper(f,errors='replace')
        #wf = f
        count = 0
        pageid_list = []
        for line in wf:
            count += 1
            info_list = regexparser.findall(line)
            #print('Length',len(info_list))
            valid_pages = reduce2ns(info_list,ns)
            if valid_pages:
                pageid_list += valid_pages
            if (count % 100) == 0:
                print(count)
    print('time:', time.time() - start)
    print('Iterations', count)
    return pageid_list

# %%
p_list = file2df(redirect_file,redirectR,reduce2ns_redirect,'0')
# Out:
# 100
# 200
# 300
# 400
# time: 14020.14691734314
# Iterations 498

# %%
len(p_list)
# Out:
# 8500104

# %%
p_list = file2df(pageid_file,pageidR,reduce2ns_page,'0')
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# time: 15281.054086208344
# Iterations 5364

# %%
len(p_list)
# Out:
# 14050827

# %%
p_list = file2df(pagelinks_file,pagelinksR,reduce2ns_pagelinks,'0')
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700

# %%
58/60
# Out:
# 0.9666666666666667

# %%
print('value {}'.format(int(58/60)))
# Out:
# value 0
