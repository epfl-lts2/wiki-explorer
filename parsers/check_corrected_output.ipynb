# %%
import pandas as pd

# %%
df = pd.read_parquet('/home/benjamin/wikipedia/Wikipedia/pagelinks_corrected1.parquet')

# %%
df
# Out:
#                                                      source  \
# 0                                                    EBCDIC
# 1                                                    EBCDIC
# 2                                                    EBCDIC
# 3                                                    EBCDIC
# 4                                                    EBCDIC
# 5                                                    EBCDIC
# 6                                                    EBCDIC
# 7                                                    EBCDIC
# 8                                                  IBM_3270
# 9                                                  IBM_3270
# 10                                                 IBM_3270
# 11                                                 IBM_3270
# 12                                                 IBM_3270
# 13                                                 IBM_3270
# 14                                                 IBM_3270
# ...

# %%
df[df.source == df.fixed_target]
# Out:
#                                                      source  \
# 79                                         Exclamation_mark
# 1360                                 Fuck_You_and_Then_Some
# 1627                              ǃKheis_Local_Municipality
# 1656                                           ǃKung_people
# 5132                                             Donnie_Vie
# 5855                                                  \"@\"
# 8307                                  Jim_Martin_(musician)
# 8712                                           \"V\"_device
# 8802                               \"Chūsotsu\"_\"Chūkara\"
# 9011                                                  1980s
# 10185           Voyage_to_the_Bottom_of_the_Sea_(TV_series)
# 10931     El_mono_Hernández_Cork_Forest_Flora_and_Fauna_...
# 11165     List_of_The_Sopranos_characters_in_the_Luperta...
# 11180                                                  WVCO
# 12379                                                  HTML
# ...

# %%
df[df.duplicated()]
# Out:
#                                                  source  \
# 13                                             IBM_3270
# 28                                        Code_page_437
# 41                                           EBCDIC_037
# 53                                           EBCDIC_285
# 67                                        Code_page_866
# 76                                    Symbol_(typeface)
# 93                                          EBCDIC_1047
# 105                                          EBCDIC_500
# 114                                            KPS_9566
# 131                                           GSM_03.38
# 144                                       Code_page_875
# 155                                       Code_page_864
# 170                                       Czech_Braille
# 180                                      Slovak_Braille
# 198                               Computer_Braille_Code
# 211                                          EBCDIC_273
# ...
